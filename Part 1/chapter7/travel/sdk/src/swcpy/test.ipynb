# %%
import httpx
import swc_config as config
from schemas import Hotel, Booking_Item, Booking_revenue_status, Hotel_prices, Inventory
from schemas import Occupancy_rate, Revenue_performance, Optimized_revenue
from schemas import Flight, Aircraft, Flight_overview, Flight_prices, Flight_popularity, Flight_inventory
from schemas import Customer, Customer_payments, Payments_overview
from schemas import Customer_hotel_preferences, Customer_flight_class, Customer_flight_preferences
from schemas import Events, Counts

from typing import List
import backoff
import logging
logger = logging.getLogger(__name__)

# %%
class SWCCLient: 
    def __init__(self, swc_base_url: str): 
        self.swc_base_url = swc_base_url 
    def get_health_check(self): 
        # make the API call 
        with httpx.Client(base_url=self.swc_base_url) as client: 
            return client.get("/")

# %% [markdown]
# source .venv/bin/activate
#
# deactivate

# %%
swc = SWCCLient

# %%
swc.get_health_check(swc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 swc.get_health_check(swc)
#
# Cell In[9], line 6, in SWCCLient.get_health_check(self)
#       4 def get_health_check(self):
#       5     # make the API call
# ----> 6     with httpx.Client(base_url=self.swc_base_url) as client:
#       7         return client.get("/")
#
# AttributeError: type object 'SWCCLient' has no attribute 'swc_base_url'

# %% [markdown]
#  Ch 5, 7, 8, 9 and 11
#
#  135-174, 204-255, 257-281, 281-296, 321-341
#
# 39, 51, 24, 15, 20 = 149 pages

# %%
(39+55+1)/149
# Out:
# 0.6375838926174496
