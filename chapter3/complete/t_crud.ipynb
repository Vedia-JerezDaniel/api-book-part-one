# %%
import t_connect
import pandas as pd

# %%
db = t_connect.SessionLocal()
engine = t_connect.engine

# %%
# Out:
#      event_id entity_id                   event_ts            event_name  \
# 0    e4375b32    EVT001  2026-08-28 00:00:00+02:00              Mad Cool
# 1    32e3a9fe    EVT001  2026-08-28 00:00:00+02:00              Mad Cool
# 2    11cde1df    EVT001  2026-08-28 00:00:00+02:00              Mad Cool
# 3    1ddde0b4    EVT001  2026-08-28 00:00:00+02:00              Mad Cool
# 4    9f9b52e6    EVT001  2026-08-28 00:00:00+02:00              Mad Cool
# ..        ...       ...                        ...                   ...
# 715  cdf2ac35    EVT010  2026-10-07 00:00:00+02:00  BCN Tour and Flavors
# 716  1206a95e    EVT010  2026-10-07 00:00:00+02:00  BCN Tour and Flavors
# 717  7519057e    EVT010  2026-10-07 00:00:00+02:00  BCN Tour and Flavors
# 718  bc2e5285    EVT010  2026-10-07 00:00:00+02:00  BCN Tour and Flavors
# 719  613eb542    EVT010  2026-10-07 00:00:00+02:00  BCN Tour and Flavors
#
#          payload customer_id customer_id2  price_event              city
# ...
