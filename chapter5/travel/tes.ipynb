# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fastapi import Depends, FastAPI, HTTPException, Query
# from sqlalchemy.orm import Session
# from datetime import date

import crud, schemas

# %%
records
# Out:
# [{'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '46898e5c',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 35926.74,
#   'total_bookings': 728.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '46898e5c',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 17963.37,
#   'total_bookings': 960.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '844f140d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 14153.67,
#   'total_bookings': 98.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'd2423176',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 13983.78,
#   'total_bookings': 1000.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '1bd5ed57',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 13888.98,
#   'total_bookings': 189.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '077545c0',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 4,
#   'total_payments': 9480.48,
#   'total_bookings': 4252.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'e3a6f945',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 8209.68,
#   'total_bookings': 836.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '19b3cc88',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 7625.32,
#   'total_bookings': 804.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '19b3cc88',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 7625.32,
#   'total_bookings': 149.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'c03c69c5',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 6975.92,
#   'total_bookings': 125.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '51229442',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4236.42,
#   'total_bookings': 835.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '51229442',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4236.42,
#   'total_bookings': 188.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '89e2635c',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4163.82,
#   'total_bookings': 165.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '89e2635c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4163.82,
#   'total_bookings': 585.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'c5007c53',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 2785.37,
#   'total_bookings': 575.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'c5007c53',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 2785.37,
#   'total_bookings': 1099.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '02b5a103',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 2561.79,
#   'total_bookings': 1852.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '15ae9ac7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 2258.63,
#   'total_bookings': 1892.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8f0fefb7',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 4,
#   'total_payments': 2010.44,
#   'total_bookings': 4297.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'd2dd249d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 1950.67,
#   'total_bookings': 1770.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '371f8a70',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 1612.98,
#   'total_bookings': 2474.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'eaa0defc',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 1572.8,
#   'total_bookings': 228.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'eaa0defc',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 1572.8,
#   'total_bookings': 142.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'e0c7d58b',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 1238.35,
#   'total_bookings': 243.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '2ab6f6bc',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 1083.84,
#   'total_bookings': 1583.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '344c0cc0',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 1059.04,
#   'total_bookings': 878.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '29696027',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 890.14,
#   'total_bookings': 280.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '5620c9cc',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 828.77,
#   'total_bookings': 131.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '371f8a70',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 806.49,
#   'total_bookings': 1190.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '26f1e58a',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 805.44,
#   'total_bookings': 1176.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '11339f9b',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 785.42,
#   'total_bookings': 143.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '90eb48ab',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 739.32,
#   'total_bookings': 3300.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '3c6e644e',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 724.94,
#   'total_bookings': 2134.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'c75f27fb',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 718.38,
#   'total_bookings': 2278.0,
#   'avg_days_to_pay': 4.5,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'e6720a59',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 710.15,
#   'total_bookings': 996.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '2fee01ed',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 690.33,
#   'total_bookings': 2391.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8c9cd4c2',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 603.24,
#   'total_bookings': 1752.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'a187c1d1',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 568.11,
#   'total_bookings': 1585.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '2fee01ed',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 508.2,
#   'total_bookings': 2391.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8f0fefb7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 502.61,
#   'total_bookings': 2120.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1e6cf74d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 463.08,
#   'total_bookings': 726.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '2fee01ed',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 460.22,
#   'total_bookings': 900.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '60da3a78',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 452.54,
#   'total_bookings': 2742.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '5b807a60',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 384.78,
#   'total_bookings': 977.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'f215ee7a',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 377.52,
#   'total_bookings': 1605.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6f3df24c',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 370.95,
#   'total_bookings': 1424.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '28f5bac6',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 369.7,
#   'total_bookings': 3010.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '3c6e644e',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 362.47,
#   'total_bookings': 145.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'cae6a133',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 348.48,
#   'total_bookings': 1394.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '325086de',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 347.19,
#   'total_bookings': 2898.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '325086de',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 347.19,
#   'total_bookings': 1716.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '54cd9417',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 346.06,
#   'total_bookings': 2540.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '2fee01ed',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 338.8,
#   'total_bookings': 900.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f8701f78',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 333.29,
#   'total_bookings': 473.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '74ecdd17',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 317.02,
#   'total_bookings': 369.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8c9cd4c2',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 301.62,
#   'total_bookings': 1296.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '1c1f026d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 301.29,
#   'total_bookings': 3282.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'c8828009',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 295.24,
#   'total_bookings': 1018.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'b1fa0584',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 275.88,
#   'total_bookings': 3551.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'a8e00fa8',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 268.62,
#   'total_bookings': 1249.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'e9bec207',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 264.99,
#   'total_bookings': 505.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '1a8afe2d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 257.73,
#   'total_bookings': 2781.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '869aa9e5',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 193.6,
#   'total_bookings': 3831.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'b6912e98',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 192.39,
#   'total_bookings': 1936.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'b6912e98',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 192.39,
#   'total_bookings': 766.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '0f58766b',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 183.92,
#   'total_bookings': 1430.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '3d5bf0c3',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 181.5,
#   'total_bookings': 2727.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '114db53d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 178.5,
#   'total_bookings': 143.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '7db037a9',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 177.87,
#   'total_bookings': 855.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '1a8afe2d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 171.82,
#   'total_bookings': 2137.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6e8afdb9',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 168.19,
#   'total_bookings': 532.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8fd62e85',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 166.98,
#   'total_bookings': 1672.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '74ecdd17',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 140.36,
#   'total_bookings': 369.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '402defd3',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 139.15,
#   'total_bookings': 245.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '99f2e8b7',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 135.52,
#   'total_bookings': 122.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '99f2e8b7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 135.52,
#   'total_bookings': 757.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8f8a6047',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 119.79,
#   'total_bookings': 1156.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '47a5134a',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 108.9,
#   'total_bookings': 110.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '063de543',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 102.85,
#   'total_bookings': 1407.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '001d93f0',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 101.64,
#   'total_bookings': 770.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '1c1f026d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 100.43,
#   'total_bookings': 949.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '57905a5c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 99.22,
#   'total_bookings': 2632.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '869aa9e5',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 96.8,
#   'total_bookings': 842.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '0f58766b',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 91.96,
#   'total_bookings': 1373.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '267866bf',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 89.54,
#   'total_bookings': 837.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'cb047f4f',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 88.33,
#   'total_bookings': 232.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6b6b6da2',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 84.7,
#   'total_bookings': 124.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'cb047f4f',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 71.39,
#   'total_bookings': 232.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'aa914110',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 71.39,
#   'total_bookings': 1400.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f9b1da8c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 68.97,
#   'total_bookings': 200.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f9b1da8c',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 68.97,
#   'total_bookings': 1996.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '26f1e58a',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 66.55,
#   'total_bookings': 1176.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '2a8cf94b',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 64.13,
#   'total_bookings': 1527.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': 'e96e3c94',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 61.71,
#   'total_bookings': 1330.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'CARD',
#   'customer_id': '875d2dbe',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 96.0,
#   'avg_days_to_pay': 5.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f8b1e349',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 1970.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '518abb91',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 1381.0,
#   'avg_days_to_pay': 1.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 1.0,
#   'payment_month': 'JANUARY',
#   'method': 'PAYPAL',
#   'customer_id': '001d93f0',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 50.82,
#   'total_bookings': 1510.0,
#   'avg_days_to_pay': 8.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '02b5a103',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 110414.1,
#   'total_bookings': 1852.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '90eb48ab',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 50935.9,
#   'total_bookings': 6600.0,
#   'avg_days_to_pay': 11.5,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1fa35020',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 3,
#   'total_payments': 45176.01,
#   'total_bookings': 5268.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '0acd98ff',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 31455.22,
#   'total_bookings': 586.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '636a90e5',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 28963.12,
#   'total_bookings': 2573.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1e5c3e96',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 27369.86,
#   'total_bookings': 3716.0,
#   'avg_days_to_pay': 15.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '5e1740c0',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 25235.37,
#   'total_bookings': 2856.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '406416dd',
#   'booking_type': 'AIR',
#   'count_payments': 3,
#   'count_bookings': 1,
#   'total_payments': 19715.68,
#   'total_bookings': 372.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '077545c0',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 4,
#   'total_payments': 17541.08,
#   'total_bookings': 4252.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '0acd98ff',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 15727.61,
#   'total_bookings': 286.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '03f27563',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 15674.5,
#   'total_bookings': 949.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '03f27563',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 15674.5,
#   'total_bookings': 853.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '636a90e5',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 14481.56,
#   'total_bookings': 569.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8f0fefb7',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 4,
#   'total_payments': 14132.04,
#   'total_bookings': 4297.0,
#   'avg_days_to_pay': 14.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '0e4f72f2',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 13684.93,
#   'total_bookings': 196.0,
#   'avg_days_to_pay': 15.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1e5c3e96',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 13684.93,
#   'total_bookings': 1233.0,
#   'avg_days_to_pay': 15.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'b48a4586',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 12592.94,
#   'total_bookings': 2954.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'b48a4586',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 12592.94,
#   'total_bookings': 3063.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '5881435d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 12284.96,
#   'total_bookings': 1984.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '4f911c69',
#   'booking_type': 'AIR',
#   'count_payments': 7,
#   'count_bookings': 2,
#   'total_payments': 12025.54,
#   'total_bookings': 6398.0,
#   'avg_days_to_pay': 10.714285714285714,
#   'failure_rate_percent': 28.57},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'bd63282d',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 11745.96,
#   'total_bookings': 1378.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '51229442',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 11696.37,
#   'total_bookings': 376.0,
#   'avg_days_to_pay': 14.5,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '51229442',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 11696.37,
#   'total_bookings': 1670.0,
#   'avg_days_to_pay': 14.5,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '59540e34',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 11132.12,
#   'total_bookings': 1234.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '57905a5c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 10316.44,
#   'total_bookings': 2632.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1a8afe2d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 9793.92,
#   'total_bookings': 2781.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '767dbf58',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 9368.08,
#   'total_bookings': 740.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '7a846c2f',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 9194.54,
#   'total_bookings': 1256.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '08096c1f',
#   'booking_type': 'AIR',
#   'count_payments': 4,
#   'count_bookings': 1,
#   'total_payments': 8093.29,
#   'total_bookings': 980.0,
#   'avg_days_to_pay': 11.5,
#   'failure_rate_percent': 25.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '422d896c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 7499.29,
#   'total_bookings': 642.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '422d896c',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 7499.29,
#   'total_bookings': 125.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8fa493ce',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 7284.98,
#   'total_bookings': 2737.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'b1947cb6',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 7212.54,
#   'total_bookings': 1692.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'b83d9ca7',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 7195.16,
#   'total_bookings': 3354.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'a8e00fa8',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 7094.4,
#   'total_bookings': 1249.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'ca875942',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 6970.28,
#   'total_bookings': 5724.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6b6b6da2',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 6740.74,
#   'total_bookings': 124.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1a8afe2d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 6529.28,
#   'total_bookings': 2137.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'b1fa0584',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 6507.24,
#   'total_bookings': 7102.0,
#   'avg_days_to_pay': 10.5,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '13e2c732',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 6447.48,
#   'total_bookings': 3184.0,
#   'avg_days_to_pay': 12.5,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '497fb030',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 6302.28,
#   'total_bookings': 4162.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '3dada837',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 5559.09,
#   'total_bookings': 1634.0,
#   'avg_days_to_pay': 14.0,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6f3df24c',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 5522.98,
#   'total_bookings': 2848.0,
#   'avg_days_to_pay': 12.5,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'b6eceef7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 5431.9,
#   'total_bookings': 1596.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'e9bec207',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 3,
#   'total_payments': 5286.96,
#   'total_bookings': 1010.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '02961c5a',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 5096.75,
#   'total_bookings': 356.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '02961c5a',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 5096.75,
#   'total_bookings': 2576.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'dc161f95',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 3,
#   'total_payments': 5024.19,
#   'total_bookings': 750.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '1e6cf74d',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 4982.6,
#   'total_bookings': 1452.0,
#   'avg_days_to_pay': 11.5,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '13e9a3ab',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 2,
#   'total_payments': 4979.46,
#   'total_bookings': 1490.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '107484d5',
#   'booking_type': 'AIR',
#   'count_payments': 3,
#   'count_bookings': 1,
#   'total_payments': 4766.96,
#   'total_bookings': 732.0,
#   'avg_days_to_pay': 10.666666666666666,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '107484d5',
#   'booking_type': 'HOTEL',
#   'count_payments': 3,
#   'count_bookings': 1,
#   'total_payments': 4766.96,
#   'total_bookings': 2934.0,
#   'avg_days_to_pay': 10.666666666666666,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '99f2e8b7',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 4753.23,
#   'total_bookings': 1514.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '99f2e8b7',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 4753.23,
#   'total_bookings': 244.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '02b5a103',
#   'booking_type': 'HOTEL',
#   'count_payments': 3,
#   'count_bookings': 3,
#   'total_payments': 4731.96,
#   'total_bookings': 5556.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 33.33},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '763b5033',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4699.99,
#   'total_bookings': 1852.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '767dbf58',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4684.04,
#   'total_bookings': 792.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'e094871a',
#   'booking_type': 'HOTEL',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 4649.8,
#   'total_bookings': 1536.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '5c1272b3',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4565.84,
#   'total_bookings': 621.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '063de543',
#   'booking_type': 'HOTEL',
#   'count_payments': 3,
#   'count_bookings': 1,
#   'total_payments': 4548.31,
#   'total_bookings': 4221.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 33.33},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'abda005a',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4522.75,
#   'total_bookings': 1705.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '1d3d2bda',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 4437.13,
#   'total_bookings': 183.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '1bd5ed57',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 4311.52,
#   'total_bookings': 378.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 50.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'f8701f78',
#   'booking_type': 'HOTEL',
#   'count_payments': 3,
#   'count_bookings': 1,
#   'total_payments': 4209.73,
#   'total_bookings': 1419.0,
#   'avg_days_to_pay': 13.333333333333334,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
# ...
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '63832a3d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 147.62,
#   'total_bookings': 268.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'e10e2423',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 147.62,
#   'total_bookings': 2808.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '0e4f72f2',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 146.41,
#   'total_bookings': 196.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '114db53d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 145.2,
#   'total_bookings': 143.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '5620c9cc',
#   'booking_type': 'AIR',
#   'count_payments': 2,
#   'count_bookings': 1,
#   'total_payments': 143.99,
#   'total_bookings': 262.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '51229442',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 137.94,
#   'total_bookings': 188.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '51229442',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 137.94,
#   'total_bookings': 835.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '639ab155',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 136.73,
#   'total_bookings': 221.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '102a243d',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 134.31,
#   'total_bookings': 83.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '0f58766b',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 133.96,
#   'total_bookings': 1373.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '267866bf',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 133.1,
#   'total_bookings': 837.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'ed104453',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 133.1,
#   'total_bookings': 438.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '0c9ea52e',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 131.89,
#   'total_bookings': 1192.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '975a8d58',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 119.79,
#   'total_bookings': 135.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'fc22dc2a',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 118.58,
#   'total_bookings': 172.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'fc22dc2a',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 118.58,
#   'total_bookings': 1094.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '1f9779a5',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 118.58,
#   'total_bookings': 1055.0,
#   'avg_days_to_pay': 15.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'b9a46334',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 118.58,
#   'total_bookings': 806.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'ff5c0ad3',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 102.85,
#   'total_bookings': 1357.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '1d3d2bda',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 102.85,
#   'total_bookings': 183.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '94ba147e',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 102.85,
#   'total_bookings': 2299.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'ff5c0ad3',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 102.85,
#   'total_bookings': 747.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '8f0fefb7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 101.64,
#   'total_bookings': 2120.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'eaa0defc',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 101.64,
#   'total_bookings': 228.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'eaa0defc',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 101.64,
#   'total_bookings': 142.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '6e8afdb9',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 101.64,
#   'total_bookings': 532.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'c8828009',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 101.64,
#   'total_bookings': 1018.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'cc6a14d7',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 99.22,
#   'total_bookings': 204.0,
#   'avg_days_to_pay': 14.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'cc6a14d7',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 99.22,
#   'total_bookings': 80.0,
#   'avg_days_to_pay': 14.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'dfe87ee6',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 2,
#   'total_payments': 99.22,
#   'total_bookings': 2298.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '7ae79fd3',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 94.38,
#   'total_bookings': 1296.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'd2dd249d',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 93.17,
#   'total_bookings': 1770.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '76a74baf',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 93.17,
#   'total_bookings': 660.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'e176c4a4',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 89.54,
#   'total_bookings': 207.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '3d5bf0c3',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 79.86,
#   'total_bookings': 2727.0,
#   'avg_days_to_pay': 11.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'c3fc1ab2',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 77.44,
#   'total_bookings': 245.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'd25a636b',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 76.23,
#   'total_bookings': 112.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'c4f7cdd5',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 76.23,
#   'total_bookings': 247.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': 'c4f7cdd5',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 76.23,
#   'total_bookings': 853.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '8047f4c9',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 75.02,
#   'total_bookings': 127.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '325086de',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 73.81,
#   'total_bookings': 2898.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '325086de',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 73.81,
#   'total_bookings': 1716.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '00c9b43b',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 60.5,
#   'total_bookings': 513.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '24712329',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 60.5,
#   'total_bookings': 707.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '24712329',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 60.5,
#   'total_bookings': 869.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 100.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f1cf4895',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 56.87,
#   'total_bookings': 180.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '5ce4eb4c',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 114.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'CARD',
#   'customer_id': '5ce4eb4c',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 400.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '20a706d1',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 54.45,
#   'total_bookings': 1559.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'f5f465cf',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 53.24,
#   'total_bookings': 1120.0,
#   'avg_days_to_pay': 12.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': '2f284839',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 52.03,
#   'total_bookings': 1414.0,
#   'avg_days_to_pay': 10.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'dfe87ee6',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 49.61,
#   'total_bookings': 2484.0,
#   'avg_days_to_pay': 9.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'c4f7cdd5',
#   'booking_type': 'AIR',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 48.4,
#   'total_bookings': 247.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0},
#  {'payment_month_num': 2.0,
#   'payment_month': 'FEBRUARY',
#   'method': 'PAYPAL',
#   'customer_id': 'c4f7cdd5',
#   'booking_type': 'HOTEL',
#   'count_payments': 1,
#   'count_bookings': 1,
#   'total_payments': 48.4,
#   'total_bookings': 853.0,
#   'avg_days_to_pay': 13.0,
#   'failure_rate_percent': 0.0}]

# %%
query = crud.qe_e
df = crud.execute_query_to_dataframe(query)
# df = df.fillna('N/A')
records = df.to_dict(orient='records')
[schemas.Events(**row) for row in records]
# Out:
# ✅ Conection granted with psycopg2
# /home/dani/API/api-book-part-one/chapter5/travel/crud.py:59: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = psql.read_sql_query(query, conn, params=params)
# [Events(event_name='Hamilton Broadway', city='New York, USA', customers_assistance=82, average_price=2000.0, total_revenue=164000),
#  Events(event_name='Madrid Open Tennis', city='Madrid, Spain', customers_assistance=66, average_price=800.0, total_revenue=52800),
#  Events(event_name='Dubai Tour', city='Dubai, UAE', customers_assistance=73, average_price=450.0, total_revenue=32850),
#  Events(event_name='BCN Tour and Flavors', city='Barcelona, Spain', customers_assistance=70, average_price=200.0, total_revenue=14000),
#  Events(event_name='Paris Fashion Week', city='Paris, France', customers_assistance=70, average_price=180.0, total_revenue=12600),
#  Events(event_name='Coldplay Concert', city='Barcelona, Spain', customers_assistance=70, average_price=200.0, total_revenue=14000),
#  Events(event_name='London Pass', city='London, UK', customers_assistance=81, average_price=400.0, total_revenue=32400),
#  Events(event_name='Dubai Shopping Festival', city='Dubai, UAE', customers_assistance=67, average_price=1500.0, total_revenue=100500),
#  Events(event_name='Mad Cool', city='Madrid, Spain', customers_assistance=59, average_price=60.0, total_revenue=3540),
#  Events(event_name='Oktoberfest Palma', city='Palma, Spain', customers_assistance=82, average_price=100.0, total_revenue=8200)]

# %%
records
# Out:
# [{'hotel_id': 'fc55b3c4',
#   'name': 'Burj Al Arab Jumeirah',
#   'city': 'Dubai',
#   'country': 'UAE',
#   'total_bookings': 7,
#   'unique_customers': 7,
#   'total_revenue': 15464.0,
#   'average_revenue': 2209.14},
#  {'hotel_id': 'a6065b00',
#   'name': 'The Plaza',
#   'city': 'New York',
#   'country': 'USA',
#   'total_bookings': 8,
#   'unique_customers': 7,
#   'total_revenue': 10319.0,
#   'average_revenue': 1289.88},
#  {'hotel_id': '1ad4f8c1',
#   'name': 'Le Meurice',
#   'city': 'Paris',
#   'country': 'France',
#   'total_bookings': 9,
#   'unique_customers': 9,
#   'total_revenue': 9921.0,
#   'average_revenue': 1102.33},
#  {'hotel_id': 'e5d181db',
#   'name': 'The Savoy',
#   'city': 'London',
#   'country': 'United Kingdom',
#   'total_bookings': 8,
#   'unique_customers': 7,
#   'total_revenue': 5966.0,
#   'average_revenue': 745.75},
#  {'hotel_id': '86a8b017',
#   'name': 'Hotel Cap Rocat',
#   'city': 'Palma',
#   'country': 'Spain',
#   'total_bookings': 4,
#   'unique_customers': 4,
#   'total_revenue': 2735.0,
#   'average_revenue': 683.75},
#  {'hotel_id': '4c9692b3',
#   'name': 'Hotel Mar',
#   'city': 'Barcelona',
#   'country': 'Spain',
#   'total_bookings': 7,
#   'unique_customers': 7,
#   'total_revenue': 1601.0,
#   'average_revenue': 228.71},
#  {'hotel_id': '8d1f74d7',
#   'name': 'Los Tajibos Hotel',
#   'city': 'Santa Cruz',
#   'country': 'Bolivia',
#   'total_bookings': 9,
#   'unique_customers': 9,
#   'total_revenue': 1091.0,
#   'average_revenue': 121.22},
#  {'hotel_id': '3aaf0cc6',
#   'name': 'Hotel Centro',
#   'city': 'Madrid',
#   'country': 'Spain',
#   'total_bookings': 5,
#   'unique_customers': 5,
#   'total_revenue': 929.0,
#   'average_revenue': 185.8}]

# %%
# type(records)
records = df.to_dict(orient='records')
records[1]
# Out:
# {'destination_trips': 1,
#  'destination': 'DXB',
#  'average_price': 466.0,
#  'customer_id': 'cc6a14d7',
#  'cabin_class': 'BUSINESS'}

# %%
for col in df.columns:
    df[col] = df[col].apply(
        lambda x: str(x[0]) if isinstance(x, (list, tuple)) and len(x) > 0 else 
                (str(x) if x is not None else '')
)

# %%
df_str = df.astype(str)
    
# Luego convertir los tipos correctos
resul = []
for _, row in df_str.iterrows():
    item = schemas.Customer_flight_class(
        destination_trips=int(float(row['destination_trips'])),
        destination=row['destination'],
        average_price=float(row['average_price']),
        customer_id=row['customer_id'],
        cabin_class=None if row['cabin_class'] == 'None' or row['cabin_class'] == 'nan' else row['cabin_class']
    )
    resul.append(item)

# %%
resul
# Out:
# [Customer_flight_class(destination_trips=1, destination='DXB', average_price=735.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=466.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=583.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=906.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=185.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=571.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1122.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1145.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1076.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=823.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=154.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=77.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=73.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=730.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=161.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=63.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1009.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=122.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=779.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=137.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1058.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=173.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=193.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=61.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=234.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=199.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1150.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1144.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=132.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=260.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=129.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=954.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=90.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=193.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=147.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=904.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=190.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=145.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=80.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=109.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1131.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=578.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=146.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=959.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=786.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=93.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1190.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=190.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1208.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=95.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=179.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=110.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1193.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1102.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=72.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=242.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=246.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=649.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=95.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=247.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=111.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=239.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=166.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=153.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=161.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=171.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=850.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=598.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=856.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=968.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=192.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=117.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=228.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=133.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1226.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=795.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1078.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=197.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=244.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=623.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=668.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1023.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=560.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=123.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=1003.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=164.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=195.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=928.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=239.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=812.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=167.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=962.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=131.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='CDG', average_price=243.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=82.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=478.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=657.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=562.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=1156.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=198.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=790.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=765.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='JFK', average_price=805.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=200.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=443.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=220.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=199.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=161.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=175.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='BCN', average_price=166.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1286.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='DXB', average_price=584.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price=187.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='LHR', average_price=278.0, customer=[], cabin_class='ECONOMY'),
#  Customer_flight_class(destination_trips=1, destination='SCZ', average_price=1142.0, customer=[], cabin_class='BUSINESS'),
#  Customer_flight_class(destination_trips=1, destination='PMI', average_price